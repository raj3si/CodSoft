# %% [markdown]
# <a href="https://colab.research.google.com/github/raj3si/CodSoft/blob/raj3si-patch-1/codsoft_titanic_survival.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing all the important libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings
filterwarnings(action='ignore')

# %%
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# %%
# Loading the dataset
titac=pd.read_csv("/content/Titanic-Dataset.csv")
titac.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df=titac.copy()

# %%
# Display the shape
df.shape
# Out:
# (891, 12)

# %%
# checking for null values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
mean=df['Age'].mean()
median=df['Age'].median()
mode=df['Age'].mode()[0]

# %%
# filling the age value with the mean,mode and median

# Simple fillna method
df['mean_age']=df["Age"].fillna(mean)
df['median_age']=df["Age"].fillna(median)
df["mode_age"]=df["Age"].fillna(mode)

# %%
df["imputed_age"]=df["Age"]

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 280          281         0       3              Duane, Mr. Frank    male
# 580          581         1       2   Christy, Miss. Julie Rachel  female
# 593          594         0       3            Bourke, Miss. Mary  female
# 339          340         0       1  Blackwell, Mr. Stephen Weart    male
# 180          181         0       3  Sage, Miss. Constance Gladys  female
#
#       Age  SibSp  Parch    Ticket   Fare Cabin Embarked   mean_age  \
# 280  65.0      0      0    336439   7.75   NaN        Q  65.000000
# 580  25.0      1      1    237789  30.00   NaN        S  25.000000
# 593   NaN      0      2    364848   7.75   NaN        Q  29.699118
# 339  45.0      0      0    113784  35.50     T        S  45.000000
# 180   NaN      8      2  CA. 2343  69.55   NaN        S  29.699118
#
#      median_age  mode_age  imputed_age
# 280        65.0      65.0         65.0
# 580        25.0      25.0         25.0
# 593        28.0      24.0          NaN
# 339        45.0      45.0         45.0
# 180        28.0      24.0          NaN

# %%
# info of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  mean_age     891 non-null    float64
#  13  median_age   891 non-null    float64
#  14  mode_age     891 non-null    float64
#  15  imputed_age  714 non-null    float64
# dtypes: float64(6), int64(5), object(5)
# memory usage: 111.5+ KB

# %%
df["imputed_age"][df["imputed_age"].isnull()]=df['Age'].dropna().sample(df['Age'].isnull().sum()).values

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# mean_age         0
# median_age       0
# mode_age         0
# imputed_age      0
# dtype: int64

# %%
# Showing the distribution before filling the nan values
plt.figure(figsize=(15,4))
plt.subplot(1,5,1)
sns.histplot(df["Age"],bins=20,kde=True)

# Distribution of age through mean
plt.subplot(1,5,2)
sns.histplot(df["mean_age"],bins=20,kde=True)

# Distribution of age through median
plt.subplot(1,5,3)
sns.histplot(df["median_age"],bins=20,kde=True)

# Distribution of age through mode
plt.subplot(1,5,4)
sns.histplot(df["mode_age"],bins=20,kde=True)

plt.subplot(1,5,5)
sns.histplot(df['imputed_age'],bins=20,kde=True)
plt.show()

# %%
fig=plt.figure()
ax=fig.add_subplot(111)

# original
df['Age'].plot(kind='kde',ax=ax,color="black")

# mean imputed
df['mean_age'].plot(kind='kde',ax=ax,color="red")

# median imputed
df['median_age'].plot(kind='kde',ax=ax,color="green")

# mode imputed
df['mode_age'].plot(kind='kde',ax=ax,color="blue")

# random imputed
df['imputed_age'].plot(kind='kde',ax=ax,color="brown")

# add legends
lines,labels=ax.get_legend_handles_labels()
ax.legend(lines,labels,loc="best")
plt.show()

# %%
plt.figure(figsize=(8,4))
df[['Age','mean_age',"median_age","mode_age",'imputed_age']].boxplot()
plt.show()

# %%
# variance of the age,mean_age,median_age,mode_age
print("Variance of age:",df["Age"].var())
print("Variance of mean age:",df['mean_age'].var())
print("Variance of median age:",df['median_age'].var())
print("Variance of mode age:",df['mode_age'].var())
print("Variance of random age:",df['imputed_age'].var())
# Out:
# Variance of age: 211.01912474630802
# Variance of mean age: 169.0523999372108
# Variance of median age: 169.51249827942345
# Variance of mode age: 174.22869485188968
# Variance of random age: 206.9125038406537

# %%
# fill the embarked values
df['mode_embarked']=df['Embarked'].fillna(df["Embarked"].mode()[0])

# %%
# fill the cabin value
df["mode_cabin"]=df['Cabin'].fillna(df["Cabin"].mode()[0])

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'mean_age',
#        'median_age', 'mode_age', 'imputed_age', 'mode_embarked', 'mode_cabin'],
#       dtype='object')

# %%
# droping useless columns
df.drop(columns=["PassengerId","Name","Embarked","mode_cabin","Ticket","Cabin","Age","mean_age","median_age","mode_age"],axis=1,inplace=True)

# %%
df.groupby('Survived').mean()
# Out:
#             Pclass     SibSp     Parch       Fare  imputed_age
# Survived
# 0         2.531876  0.553734  0.329690  22.117887    30.402095
# 1         1.950292  0.473684  0.464912  48.395408    28.443480

# %%
df.groupby("Sex")[["Survived"]].mean()
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
df[['SibSp',"Survived"]].groupby(['SibSp'],as_index=False).mean().sort_values(by="Survived",ascending=False)
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %%
df[['Pclass','Survived']].groupby(['Pclass'],as_index=False).mean().sort_values(by="Survived",ascending=False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
df[["mode_embarked","Survived"]].groupby(['mode_embarked'],as_index=False).mean().sort_values(by='Survived',ascending=False)
# Out:
#   mode_embarked  Survived
# 0             C  0.553571
# 1             Q  0.389610
# 2             S  0.339009

# %%
plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
sns.kdeplot(df['Fare'])
plt.title("Fare distribution")

plt.subplot(1,2,2)
sns.kdeplot(df["Parch"])
plt.title("Parch distribution")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
plt.show()

# %%
df.sample(5)
# Out:
#      Survived  Pclass   Sex  SibSp  Parch     Fare  imputed_age mode_embarked
# 36          1       3  male      0      0   7.2292         19.0             C
# 452         0       1  male      0      0  27.7500         30.0             C
# 579         1       3  male      0      0   7.9250         32.0             S
# 63          0       3  male      3      2  27.9000          4.0             S
# 470         0       3  male      0      0   7.2500         21.0             S

# %%
x=df.iloc[:,1:]

# %%
x.sample(2)
# Out:
#      Pclass   Sex  SibSp  Parch    Fare  imputed_age mode_embarked
# 101       3  male      0      0  7.8958         20.0             S
# 95        3  male      0      0  8.0500         22.0             S

# %%
y=df.iloc[:,:1]

# %%
y.sample(2)
# Out:
#      Survived
# 860         0
# 817         0

# %%
gen={"male":0,"female":1}
x["Sex"]=x['Sex'].apply(lambda x:gen[x])

# %%
embark={"C":0,"Q":1,"S":2}
x["mode_embarked"]=x["mode_embarked"].apply(lambda x:embark[x])

# %%
x
# Out:
#      Pclass  Sex  SibSp  Parch     Fare  imputed_age  mode_embarked
# 0         3    0      1      0   7.2500         22.0              2
# 1         1    1      1      0  71.2833         38.0              0
# 2         3    1      0      0   7.9250         26.0              2
# 3         1    1      1      0  53.1000         35.0              2
# 4         3    0      0      0   8.0500         35.0              2
# ..      ...  ...    ...    ...      ...          ...            ...
# 886       2    0      0      0  13.0000         27.0              2
# 887       1    1      0      0  30.0000         19.0              2
# 888       3    1      1      2  23.4500         36.0              2
# 889       1    0      0      0  30.0000         26.0              0
# 890       3    0      0      0   7.7500         32.0              1
#
# [891 rows x 7 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
# Training testing and spliting the model
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# transformer=ColumnTransformer(transformer=[
#     ("tnf1",OrdinalEncoder(categories=[["male","female"]]),['Sex']),
#     ("tnf2",OrdinalEncoder(categories=[["C","Q","S"]]),["mode_embarked"])
# ],remainder="passthrough")

# %%
# Using logistic regression
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print("Accuracy:",accuracy_score(y_test,y_pred))
# Out:
# Accuracy: 0.7932960893854749

# %%
# confusion metrics
from sklearn.metrics import confusion_matrix,classification_report
confusion_mat=confusion_matrix(y_test,y_pred)
print(confusion_mat)
print(classification_report(y_test,y_pred))
# Out:
# [[90 15]
#  [22 52]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.86      0.83       105
#            1       0.78      0.70      0.74        74
#
#     accuracy                           0.79       179
#    macro avg       0.79      0.78      0.78       179
# weighted avg       0.79      0.79      0.79       179

# %%
# using support vector
from sklearn.svm import SVC
model1=SVC()
model1.fit(x_train,y_train)

pred_y=model1.predict(x_test)
print("accuracy",accuracy_score(pred_y,y_test))
# Out:
# accuracy 0.6536312849162011

# %%
confusion_mat=confusion_matrix(y_test,pred_y)
print(confusion_mat)
print(classification_report(y_test,pred_y))
# Out:
# [[99  6]
#  [56 18]]
#               precision    recall  f1-score   support
#
#            0       0.64      0.94      0.76       105
#            1       0.75      0.24      0.37        74
#
#     accuracy                           0.65       179
#    macro avg       0.69      0.59      0.56       179
# weighted avg       0.68      0.65      0.60       179

# %%
# Using KNN Neighbors
from sklearn.neighbors import KNeighborsClassifier
model2=KNeighborsClassifier()

model2.fit(x_train,y_train)
y_pred2=model2.predict(x_test)

print("Accuracy:",accuracy_score(y_test,y_pred2))
# Out:
# Accuracy: 0.7094972067039106

# %%
confusion_mat=confusion_matrix(y_test,y_pred2)
print(confusion_mat)
print(classification_report(y_test,y_pred2))
# Out:
# [[86 19]
#  [33 41]]
#               precision    recall  f1-score   support
#
#            0       0.72      0.82      0.77       105
#            1       0.68      0.55      0.61        74
#
#     accuracy                           0.71       179
#    macro avg       0.70      0.69      0.69       179
# weighted avg       0.71      0.71      0.70       179

# %%
# using GaussianNB
from sklearn.naive_bayes import GaussianNB
model3=GaussianNB()

model3.fit(x_train,y_train)

y_pred3=model3.predict(x_test)

print("Accuracy:",accuracy_score(y_test,y_pred3))
# Out:
# Accuracy: 0.776536312849162

# %%
confusion_mat=confusion_matrix(y_test,y_pred3)
print(confusion_mat)
print(classification_report(y_test,y_pred3))
# Out:
# [[82 23]
#  [17 57]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.78      0.80       105
#            1       0.71      0.77      0.74        74
#
#     accuracy                           0.78       179
#    macro avg       0.77      0.78      0.77       179
# weighted avg       0.78      0.78      0.78       179

# %%
# Using decision tree
from sklearn.tree import DecisionTreeClassifier
model4=DecisionTreeClassifier(criterion='entropy',random_state=42)

model4.fit(x_train,y_train)

y_pred4=model4.predict(x_test)

print("Accuracy:",accuracy_score(y_test,y_pred4))
# Out:
# Accuracy: 0.7877094972067039

# %%
confusion_mat=confusion_matrix(y_test,y_pred4)
print(confusion_mat)
print(classification_report(y_test,y_pred4))
# Out:
# [[82 23]
#  [15 59]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.78      0.81       105
#            1       0.72      0.80      0.76        74
#
#     accuracy                           0.79       179
#    macro avg       0.78      0.79      0.78       179
# weighted avg       0.79      0.79      0.79       179

# %%
result=pd.DataFrame({
    "Model":["Logistic Regression","Support Vector Machines","Naive Bayes","KNN","Desicion Tree"],
    "Score":[round(accuracy_score(y_test,y_pred),2),round(accuracy_score(pred_y,y_test),2),round(accuracy_score(y_test,y_pred3),2),round(accuracy_score(y_test,y_pred2),2),round(accuracy_score(y_test,y_pred4),2)]
})

# %%
result.sort_values(by='Score',ascending=False).set_index("Score")
# Out:
#                          Model
# Score
# 0.79       Logistic Regression
# 0.79             Desicion Tree
# 0.78               Naive Bayes
# 0.71                       KNN
# 0.65   Support Vector Machines
